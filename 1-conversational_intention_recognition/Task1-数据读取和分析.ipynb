# %% [markdown]
# # Task1-数据读取和分析

# %% [markdown]
# ## 读取数据集

# %%
import pandas as pd

# %%
# !wget -P ./data/ https://mirror.coggle.club/dataset/coggle-competition/intent-recognition-train.csv
# !wget -P ./data/ https://mirror.coggle.club/dataset/coggle-competition/intent-recognition-test.csv

# %%
# data_dir = 'https://mirror.coggle.club/dataset/coggle-competition/'
data_dir = './data/'
train_data = pd.read_csv(data_dir + 'intent-recognition-train.csv', sep='\t', header=None)
test_data = pd.read_csv(data_dir + 'intent-recognition-test.csv', sep='\t', header=None)

train_data[1].value_counts(normalize=True)  # 统计每个类别出现的次数和比例
# Out:
# FilmTele-Play            0.111983
# Video-Play               0.110248
# Music-Play               0.107769
# Radio-Listen             0.106198
# Alarm-Update             0.104463
# Weather-Query            0.101570
# Travel-Query             0.100826
# HomeAppliance-Control    0.100413
# Calendar-Query           0.100331
# TVProgram-Play           0.019835
# Audio-Play               0.018678
# Other                    0.017686
# Name: 1, dtype: float64

# %%
train_data[0].apply(len).describe()  # 统计每个文本的长度
# Out:
# count    12100.000000
# mean        15.138678
# std          4.872583
# min          4.000000
# 25%         12.000000
# 50%         15.000000
# 75%         18.000000
# max         54.000000
# Name: 0, dtype: float64

# %% [markdown]
# ## 中文分词

# %%
from wordcloud import WordCloud  
import matplotlib.pyplot as plt
import jieba

# %%
# !wget https://mirror.coggle.club/STHeiti-Light.ttc
# !wget -P ./data https://mirror.coggle.club/stopwords/baidu_stopwords.txt

# %%
content = ''.join(train_data[train_data[1] == 'Music-Play'][0])
words = jieba.lcut(content)

# 读取中文停用词
cn_stopwords = ' '.join(pd.read_csv('./data/baidu_stopwords.txt', header=None)[0])
words = [x for x in words if x not in cn_stopwords]
print(words)
# 中文字体，wget https://mirror.coggle.club/STHeiti-Light.ttc
# 如果不设置，云图不能展示中文
wordcloud = WordCloud(background_color = 'white', max_words = 1000, font_path = 'STHeiti-Light.ttc')
wordcloud.generate(' '.join(words))
plt.imshow(wordcloud)
plt.xticks([]); plt.yticks([])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/4v/smkbk7c539v8q47k6270z2v40000gn/T/jieba.cache
# Loading model cost 0.875 seconds.
# Prefix dict has been built successfully.
# ['随便', '播放', '一首', '专辑', '阁楼', '佛里', '歌单', '曲', '循环', '一首', '催眠', '歌', '播放', '钢琴曲', '命运', '交响曲', '我要', '听', '治愈', '日语', '歌曲', '单曲', '循环', '赵雷', '时光', '这首', '流行', '播放', '一首', '适合', '开心', '听', '歌曲', '想', '听', '顽童', '辣台', '妹能', '播放', '2011', '浪漫', '歌来', '一首', '放', '一个', '德语', '歌曲', '播放', '日语', '歌泪', '物语', '请', '一首', '吴亦凡', '英文歌', 'July', '。', '循环', '播放', '张哲瀚', '环绕', '请', '播放', '带', '戏曲', '唱腔', '专辑', '赤伶', '，', '李玉刚', '版', '循环', '播放', '时光', '这首', '流行', '呼吸', '之野里', '歌曲', '随便', '一首', '播放', '法语', '歌曲', '随机', '一首', '随机', '一曲', '山河', '电视剧', '歌', '90', '年代', '搞笑', '歌曲', '听听', '放', '一首', '扬琴', '版', '梁祝', '找', '一首', '蔡琴', '歌', '听听', '想', '播放', '张信哲', '一个', '永远', '白月光', '想', '听', '都', '，', '要余', '佳运', '唱', '一个', '2021', '古典音乐', '想', '听', '英文', '专辑', '，', 'stay', '，', '林俊杰', '完美', '降落', '播放', '，', '法老', '合唱', '随机', '播放', '一首', '纯音乐', '。', '请', '随机', '播放', '一首', '张杰', '中文歌曲', '播', '一首', '运动', '风格', '中文歌曲', '初爱', '歌', '随机', '唱', '一首', '林俊杰', '专辑', '乐行者', '随机', '播放', '治愈', '钢琴曲', '随便', '来个', '听', '顺序', '播放', '李健', '歌曲', '1999', '发行', '歌', '都', '播放', '一遍', '随机', '一首', '欢快', '一点', '浪漫', '情歌', '一首', '差', '一步', '歌儿', '播放', '一首', '应景', '《', '回到', '拉萨', '，', '我要', '郑钧', '银临', '、', '河图', '专辑', '蚍蜉', '渡海', '播放', '想', '听', '金莎唱', '爱', '魔法', '这首', '流行音乐', '一首', '许嵩', '认错', '陈', '小熊', '歌儿', '济南', '济南', '请', '播放', '吴涤', '清版', '《', '梅兰', '梅兰', '我爱你', '放', '一首', '萨克斯', '演奏', '古典音乐', '想', '听', '英文', '情歌', '顺序', '播放', '周杰伦', '专辑', '七里香', '歌', '一生', '风景', '，', '我要', '听', '隔壁', '老樊唱', '想', '播放', '一首', '表达', '爱意', '钢琴曲', '单曲', '循环', '名', '侦探', '柯南', '主题曲', '黄安', '90', '年代', '歌', '随机', '一首', '二胡', '弹奏', '人气', '歌曲', '一首', '有没有', '热血', '动漫', '配乐', '一首', '顺序', '播放', '专辑', 'Wuha', '歌曲', '2000', '歌曲', '随机', '一首', '播放', '齐秦', '冬季', '放范丞丞', '快乐', '很', '简单', '单曲', '循环', '事放', 'BEYOND', '经典', '光辉', '岁月', '随机', '一首', '2011', '歌', '听', '张国荣', '光荣', '岁月', '歌', '想', '循环', '播放', '流行', '风格', '专辑', '放', '一首', 'rap', '，', '放', '十全', '九美', '随机', '播放', '一首', '李冠森', '歌曲', '立刻', '播放', '萧忆情', '拜', '无忧', '一首', '2009', '王力宏', '曲子', '悲伤', '留给', '单曲', '循环', '播放', '找', '蔡', '徐坤', '情人', '播', '第二', '街区', '这张', '专辑', '第一首', '循环', '放给', '听', 'Bieber', 'justice', '毛', '不易', '听', '周深', '王子', '唱', '资深', '庸才', '日本', '歌手', '米津', '玄师', '日语', '歌', '随机', '一首', '2007', '王力宏', '歌', '播放', '想', '听', '古筝', '，', '一首', '铁马', '吟', '听听', '天韵', '霍尊里', '歌曲', '随机', '一首', '播放', '凤凰', '传奇', '快乐', '音乐', '播放', '屠洪刚', '专辑', '风云', '2', '歌曲', '中国娃娃', '恭喜', '恭喜', '放', '随机', '播放', '韩红', '歌单', '曲', '循环', '一个', '钢琴曲', '老', '歌手', '刀郎', '歌来', '几首', '唱', '一个', '开心', '阿拉伯语', '歌曲', '播放', 'hold', '，', 'Bieber', '唱', '想', '听任', '同祥', '唢呐', '曲到', '春来', '随机', '播放', '一首', '暗杠', '歌曲', '韩语', '歌', '随机', '一首', '俄语', '歌', '有没有', '治愈', '放', '一个', '想', '听', '郎朗', '钢琴曲', '听', '张国荣', '这张', '专辑', '歌曲', '，', '随机', '一首', '行来', '一首', '90', '年代', '英文歌', '播放', '笙', '演奏', '冬猎', '周杰伦', '叶惠美', '顺序', '播放', '播放', '林依晨', '流行歌', '非你莫属', '呼吸', '之野', '假摔', '单曲', '循环', '想', '播放', '胡彦斌', '专辑', '太歌', '歌', '唱', '一首', '英文', '流行歌曲', '王菲', '陈奕迅', '合唱', '歌曲', '传奇', '播放', '凤凰', '传奇', '歌', '顺序', '播放', '火', '孤影', '单曲', '循环', '请', '随机', '播放', '一首', '钢琴曲', '。', '有没有', '听', '想', '笑', '德语', '歌', '有没有', '适合', '表白', '氛围', '歌曲', '播放', '陈鸿宇', '步履', '不停', '歌曲', '随机', '一首', '想要', '一首', '很', '治愈', '德语', '歌', '听', '找', '2020', '人气', '歌曲', '播放', '一首', '钢琴', '弹唱', '勇气', '随机', '一首', '张国荣', '歌曲', '隔壁', '老樊', '放到', '顺序', '播放', '下周', '就要', '歌唱', '比赛', '，', '我要', '单曲', '循环', '唱支', '山歌', '党', '听', '。', '想', '听', '民谣', '南方', '姑娘', '要学', '韩语', '，', '随便', '放', '一首', '随机', '播放', '陈', '一发', '专辑', '童话', '镇里', '歌儿', '随机', '一首', '2013', '发行', '英语歌', '随机', '一首', '陈旭', '歌曲', '想', '听', '一首', '陈泓宇', '步履', '不停', '歌曲', '想', '听', '80', '年代', '英文歌', '搞笑', '英文歌', '播放', '2021', '发行', '爵士', '歌曲', '随机', '一个', '一首', '八十年代', '潘美辰', '《', '想', '听听', '随机', '播放', '一首', '70', '年代', '英文歌曲', '歌曲', '葫芦丝', '创作', '，', '顺序', '播放', '想', '听', '听', '咯', '一首', '90', '年代', '英文歌', '网络', '歌曲', '开业', '大吉', '播放', '周杰伦', '2011', '歌曲', '播放', '播放', '轻音乐', '琵琶', '语', '听', '赵雷', '成都', '。', '单曲', '播放', '霄磊', '叹郁', '孤', '低', '苦艾', '乐 ...
# ([], [])
